# %% [markdown]
# # Exploratory Data Analysis: Grade Transitions
#
# This notebook contains the experimental exploratory analysis for paper machine grade change transitions. We visualize sensor deviations, identify transition start/end indices, and perform feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load sample sensor readings
df = pd.read_csv('../../data/raw/sensor_readings_sample.csv')
print(df.head())
